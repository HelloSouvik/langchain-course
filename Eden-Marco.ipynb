# %%
from dotenv import load_dotenv, find_dotenv
import os

from langchain_core.caches import InMemoryCache
from langchain_openai import OpenAI
from langchain_openai import ChatOpenAI
import langchain

from langchain_core.messages import (
    AIMessage, 
    HumanMessage, 
    SystemMessage
)
from langchain_core.prompts import (
    ChatPromptTemplate,
    PromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
    MessagesPlaceholder
)

from langchain_community.chat_message_histories.in_memory import ChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

from langchain_community.document_loaders import *
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai  import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

# %%
load_dotenv(find_dotenv())
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
llm=ChatOpenAI(model="gpt-5-nano-2025-08-07", openai_api_key=OPENAI_API_KEY)

# %%
llm.invoke("how are you")
# Out:
# AIMessage(content='I’m here and ready to help. I don’t have feelings, but I’m functioning well. What would you like to do today?\n\nIf you’re not sure, I can help with:\n- Answering questions or explaining concepts\n- Writing or editing text\n- Solving math problems or coding questions\n- Planning projects, trips, or schedules\n- Summarizing articles or documents\n\nWhat can I assist you with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 415, 'prompt_tokens': 9, 'total_tokens': 424, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DL82W2VllnSgXtfrwhvKf7VzDtaQc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d065b-a8a1-7111-b128-e180640e8e0d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 415, 'total_tokens': 424, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})

# %%
from langchain_tavily import TavilySearch
from pydantic import BaseModel, Field
from typing import List
from langchain.agents import create_agent
from langchain.tools import tool
